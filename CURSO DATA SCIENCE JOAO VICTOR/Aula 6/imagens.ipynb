# %% [markdown]
# #### incorporando imagens online

# %%
from IPython.display import Image
imagem=Image(url='https://gartic.com.br/imgs/mural/bi/bitolino/blz.png')
print(imagem)
display(imagem)
# Out:
# <IPython.core.display.Image object>
# <img src="https://gartic.com.br/imgs/mural/bi/bitolino/blz.png"/>

# %% [markdown]
# #### plotando um grafico simples com matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([3,4,5],[100,200,300])
plt.title('titulo')
plt.show()
